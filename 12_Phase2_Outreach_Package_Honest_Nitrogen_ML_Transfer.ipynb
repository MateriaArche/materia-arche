# %% [markdown]
# # 12_Phase2_Outreach_Package
# ## Materia Arche V3.2 — Phase 2 triggered (Option A)
# ### Honest outreach templates, lab scoping, evidence summary

# %%
import pandas as pd

print("✅ Notebook 12 — Phase 2 outreach package")
# Out:
# ✅ Notebook 12 — Phase 2 outreach package

# %% [markdown]
# ## 1. Outreach templates (ready to send)

# %%
templates = {
    "Fraunhofer ISE (Primary)": {
        "Subject": "Collaboration Request – Perovskite Stability Validation Pilot",
        "Body": """Dear Fraunhofer ISE Perovskite Team,

Materia Arche has completed internal validation of an ML-orchestrated
stability prediction pipeline for perovskite solar cells.

Key results (full notebooks: github.com/MateriaArche/materia-arche):
- ML baseline: Kendall tau-b = 0.249 (p < 1e-10) on 1,543 devices
- Cross-validated: 0.257 +/- 0.012 (5-fold)
- +0.133 lift over composition-only classical baseline
- 153 candidate compositions with >20% simulated stability gain
- 9 quantum feature experiments tested (0 positive lift — quantum
  remains long-term R&D, ML baseline is the validated stack)

We are ready for external validation:
- 3 candidates (literature baseline + classical + ML-predicted)
- 5 devices per candidate, same fabrication campaign
- ISOS-style stability protocol

Evidence Package and candidate shortlist available on request.

Would you be open to a short call to discuss a collaborative pilot?

Best regards,
John
Founder & CEO, Materia Arche
john@materiaarche.com"""
    },
    "NREL (Fallback)": {
        "Subject": "Quote Request – Perovskite Stability Test Panel",
        "Body": """Dear NREL Perovskite Team,

Materia Arche has built an ML pipeline for perovskite stability
prediction (Kendall tau-b 0.249, p < 1e-10, 1,543 devices).

We are scoping external validation partners for a small test panel:
- 3 candidates, 5 devices each, ISOS-style protocol
- Full pipeline and evidence: github.com/MateriaArche/materia-arche

Could you provide a quote and timeline for this scope?

Best regards,
John
Founder & CEO, Materia Arche
john@materiaarche.com"""
    },
    "University Core (Budget)": {
        "Subject": "Quote Request – Small Perovskite Stability Campaign",
        "Body": """Dear [Lab Name] Team,

We are scoping a small perovskite stability validation campaign:
- 3 compositions, 5 devices each, ISOS-style testing
- ML-predicted candidates from our public pipeline
  (github.com/MateriaArche/materia-arche)

Could you provide a quote, timeline, and any constraints?

Best regards,
John
Founder & CEO, Materia Arche
john@materiaarche.com"""
    }
}

print("=" * 65)
print("PHASE 2 OUTREACH TEMPLATES (ready to send)")
print("=" * 65)
for lab, info in templates.items():
    print(f"\n--- {lab} ---")
    print(f"Subject: {info['Subject']}")
    print(info['Body'])

rows = [{"Lab": lab, **info} for lab, info in templates.items()]
pd.DataFrame(rows).to_csv("Phase2_Outreach_Templates.csv", index=False)
print("\n✅ Phase2_Outreach_Templates.csv exported")
# Out:
# ...
# PHASE 2 OUTREACH TEMPLATES (ready to send)
# ...
#
# --- Fraunhofer ISE (Primary) ---
# Subject: Collaboration Request – Perovskite Stability Validation Pilot
# Dear Fraunhofer ISE Perovskite Team,
#
# Materia Arche has completed internal validation of an ML-orchestrated
# stability prediction pipeline for perovskite solar cells.
#
# Key results (full notebooks: github.com/MateriaArche/materia-arche):
# - ML baseline: Kendall tau-b = 0.249 (p < 1e-10) on 1,543 devices
# - Cross-validated: 0.257 +/- 0.012 (5-fold)
# - +0.133 lift over composition-only classical baseline
# - 153 candidate compositions with >20% simulated stability gain
# - 9 quantum feature experiments tested (0 positive lift — quantum
#   remains long-term R&D, ML baseline is the validated stack)
#
# We are ready for external validation:
# - 3 candidates (literature baseline + classical + ML-predicted)
# - 5 devices per candidate, same fabrication campaign
# - ISOS-style stability protocol
#
# ...

# %% [markdown]
# ## 2. Lab scoping table

# %%
scoping = pd.DataFrame({
    'Lab': ['Fraunhofer ISE', 'NREL', 'University Core Facility'],
    'Scope': ['3 candidates x 5 devices', '3 candidates x 5 devices', '3 candidates x 5 devices'],
    'Est_Cost': ['$12K-$22K', '$8K-$15K', '$5K-$12K'],
    'Lead_Time': ['4-8 weeks', '3-6 weeks', '2-4 weeks'],
    'Priority': ['Primary', 'Fallback', 'Budget option'],
    'Protocol': ['ISOS', 'ISOS', 'ISOS-compatible']
})

print("=" * 65)
print("PHASE 2 LAB SCOPING")
print("=" * 65)
print(scoping.to_string(index=False))

scoping.to_csv("Phase2_Scoping_Table.csv", index=False)
print("\n✅ Phase2_Scoping_Table.csv exported")
# Out:
# ...
# PHASE 2 LAB SCOPING
# ...
#                      Lab                    Scope  Est_Cost Lead_Time      Priority        Protocol
#           Fraunhofer ISE 3 candidates x 5 devices $12K-$22K 4-8 weeks       Primary            ISOS
#                     NREL 3 candidates x 5 devices  $8K-$15K 3-6 weeks      Fallback            ISOS
# University Core Facility 3 candidates x 5 devices  $5K-$12K 2-4 weeks Budget option ISOS-compatible
#
# ✅ Phase2_Scoping_Table.csv exported

# %% [markdown]
# ## 3. Evidence summary for attachment

# %%
evidence = pd.DataFrame({
    "Metric": [
        "Dataset", "ML tau-b", "ML p-value", "ML lift vs classical",
        "5-fold CV tau-b", "MAE", "Candidates (>20% gain)",
        "Quantum experiments", "Best quantum lift",
        "Milestones (revised ML)", "Notebooks", "GitHub"
    ],
    "Value": [
        "1,543 devices with T80 stability",
        "0.249", "< 1e-10", "+0.133",
        "0.257 +/- 0.012", "1.305 log-hours", "153",
        "9 (0 positive lift)", "-0.0024",
        "5/5 met", "12 (01-12)",
        "github.com/MateriaArche/materia-arche"
    ]
})

print("=" * 65)
print("EVIDENCE SUMMARY (for lab attachment)")
print("=" * 65)
print(evidence.to_string(index=False))

evidence.to_csv("Evidence_Summary_Phase2.csv", index=False)
print("\n✅ Evidence_Summary_Phase2.csv exported")
# Out:
# ...
# EVIDENCE SUMMARY (for lab attachment)
# ...
#                  Metric                                 Value
#                 Dataset      1,543 devices with T80 stability
#                ML tau-b                                 0.249
#              ML p-value                               < 1e-10
#    ML lift vs classical                                +0.133
#         5-fold CV tau-b                       0.257 +/- 0.012
#                     MAE                       1.305 log-hours
#  Candidates (>20% gain)                                   153
#     Quantum experiments                   9 (0 positive lift)
#       Best quantum lift                               -0.0024
# Milestones (revised ML)                               5/5 met
#               Notebooks                            12 (01-12)
#                  GitHub github.com/MateriaArche/materia-arche
#
# ✅ Evidence_Summary_Phase2.csv exported

# %% [markdown]
# ## 4. Nitrogen ML transfer — honest assessment

# %%
print("=" * 65)
print("NITROGEN — ML METHODOLOGY TRANSFER")
print("=" * 65)
print("")
print("What transfers from perovskite to nitrogen:")
print("  - Pipeline architecture (data -> features -> model -> candidates)")
print("  - Statistical validation methodology (Kendall tau-b, CV, bootstrap)")
print("  - Evidence packaging and reproducibility framework")
print("  - Milestone-gated decision process")
print("")
print("What nitrogen still needs (not yet done):")
print("  - Catalyst composition database (no equivalent to Perovskite DB yet)")
print("  - DFT-computed binding energies as ground truth")
print("  - Domain-specific features for N2 fixation catalysis")
print("  - 3-6 months of dedicated work")
print("")
print("STATUS: ON HOLD until perovskite Phase 2 results are in.")
print("The methodology is proven. The data pipeline is not yet built.")
# Out:
# ...
# NITROGEN — ML METHODOLOGY TRANSFER
# ...
#
# What transfers from perovskite to nitrogen:
#   - Pipeline architecture (data -> features -> model -> candidates)
#   - Statistical validation methodology (Kendall tau-b, CV, bootstrap)
#   - Evidence packaging and reproducibility framework
#   - Milestone-gated decision process
#
# What nitrogen still needs (not yet done):
#   - Catalyst composition database (no equivalent to Perovskite DB yet)
#   - DFT-computed binding energies as ground truth
#   - Domain-specific features for N2 fixation catalysis
#   - 3-6 months of dedicated work
#
# STATUS: ON HOLD until perovskite Phase 2 results are in.
# The methodology is proven. The data pipeline is not yet built.

# %% [markdown]
# ## 5. Final status

# %%
print("=" * 65)
print("MATERIA ARCHE — PHASE 2 READY")
print("=" * 65)
print("")
print("Internal proof: COMPLETE")
print("  ML baseline validated (tau-b 0.249, CV stable, 153 candidates)")
print("  Quantum investigation closed (9 experiments, 0 positive lift)")
print("  Milestones revised to ML-focused: 5/5 met")
print("  Website updated: materiaarche.com")
print("")
print("Phase 2 assets ready:")
print("  - Outreach templates for 3 labs (copy-paste ready)")
print("  - Lab scoping table with costs and timelines")
print("  - Evidence summary for attachment")
print("  - Full pipeline on GitHub (12 notebooks)")
print("")
print("Next action: Send outreach email to Fraunhofer ISE.")
print("")
print("Portfolio:")
print("  Perovskite: Phase 2 ACTIVE")
print("  Nitrogen: ON HOLD (methodology proven, data pipeline needed)")
print("  Quantum: Separate R&D track (not a gate)")
# Out:
# ...
# MATERIA ARCHE — PHASE 2 READY
# ...
#
# Internal proof: COMPLETE
#   ML baseline validated (tau-b 0.249, CV stable, 153 candidates)
#   Quantum investigation closed (9 experiments, 0 positive lift)
#   Milestones revised to ML-focused: 5/5 met
#   Website updated: materiaarche.com
#
# Phase 2 assets ready:
#   - Outreach templates for 3 labs (copy-paste ready)
#   - Lab scoping table with costs and timelines
#   - Evidence summary for attachment
#   - Full pipeline on GitHub (12 notebooks)
#
# Next action: Send outreach email to Fraunhofer ISE.
#
# Portfolio:
#   Perovskite: Phase 2 ACTIVE
#   Nitrogen: ON HOLD (methodology proven, data pipeline needed)
#   Quantum: Separate R&D track (not a gate)
